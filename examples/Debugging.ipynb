# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from pandas import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Two taxon fixed map comparison
# ------------------------------

# %%
dfs = read_table('simulated_fixedMap.stats')
df = read_table('slideHopScaleTest_fixedMap.stats')

# %% [markdown]
# The clonal frame height distribution should simply be its distribution under the coalescent with a constant population size of 1. That is
#
# \begin{equation}
#     P(t_{CF})=e^{-t_{CF}}
# \end{equation}
#
# We see that this is the case for the simulated ARGs, but not the MCMC-sampled ARGs:

# %%
bins=arange(0,10,0.1)
dfs['arg.CFheight'].hist(bins=bins,normed=True, alpha=0.5, label="Simulated")
df['arg.CFheight'].hist(bins=bins, normed=True, alpha=0.5, label="MCMC")
plot(bins, exp(-bins), label=r"Truth ($e^{-t_{CF}}$)")
xlim((-.1,8))
xlabel('CF Height')
ylabel('Density')
legend()
